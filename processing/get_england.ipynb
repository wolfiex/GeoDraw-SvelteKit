# %%
import pandas as pd 
import json 
tables = json.load(open('../static/data/nomis_tables.json','r'))
tables
# Out:
# {'Adults not in employment and dependent children and persons with long-term health problems or disability for all households': '/census/2011/ks106ew',
#  'Age structure': '/census/2011/ks102ew',
#  'Age Structure': '/census/2011/ks102uk',
#  'Car or van availability': '/census/2011/qs416ew',
#  'Communal establishment residents': '/census/2011/ks405uk',
#  'Country of birth': '/census/2011/wd203ew',
#  'Dwellings, household spaces and accommodation type': '/census/2011/ks401uk',
#  'Economic activity - Females': '/census/2011/ks603uk',
#  'Economic activity - Males': '/census/2011/ks602uk',
#  'Economic activity by sex': '/census/2011/ks601ew',
#  'Economic activity': '/census/2011/st601ewla',
#  'Ethnic group': '/census/2011/wd201ew',
#  'Health and provision of unpaid care': '/census/2011/ks301uk',
#  'Hours worked': '/census/2011/st604ewla',
#  'Household composition': '/census/2011/ks105uk',
#  'Household language': '/census/2011/ks206ew',
# ...

# %%
url = "https://www.nomisweb.co.uk/api/v01/dataset/NM_145_0.data.csv?date=latest&geography=K04000001&rural_urban=0&measures=20100&select=geography_name,cell_name,obs_value"

# '/census/2011/ks102uk'




pd.read_csv(url)
# Out:
#        GEOGRAPHY_NAME            CELL_NAME   OBS_VALUE
# 0   England and Wales  All usual residents  56075912.0
# 1   England and Wales           Age 0 to 4   3496750.0
# 2   England and Wales           Age 5 to 7   1927039.0
# 3   England and Wales           Age 8 to 9   1208672.0
# 4   England and Wales         Age 10 to 14   3258677.0
# 5   England and Wales               Age 15    687994.0
# 6   England and Wales         Age 16 to 17   1391235.0
# 7   England and Wales         Age 18 to 19   1460156.0
# 8   England and Wales         Age 20 to 24   3807245.0
# 9   England and Wales         Age 25 to 29   3836609.0
# 10  England and Wales         Age 30 to 44  11515165.0
# 11  England and Wales         Age 45 to 59  10886135.0
# 12  England and Wales         Age 60 to 64   3377162.0
# 13  England and Wales         Age 65 to 74   4852833.0
# 14  England and Wales         Age 75 to 84   3115552.0
# 15  England and Wales         Age 85 to 89    825671.0
# ...
